# %%
import numpy as np
import pandas as pd

# %%
data_path = 'data'
# ratings = pd.read_csv(f'{data_path}/RatingsComments.csv')
# users = pd.read_csv(f'{data_path}/Users.csv')
points = pd.read_csv(f'{data_path}/Points.csv')
products = pd.read_csv('data/Products.csv')

# %%
companies = pd.read_csv('data/Companies.csv')
companies.head()
# Out:
#     Restaurant
# 0   McDonald's
# 1    Starbucks
# 2  Chick-fil-A
# 3    Taco Bell
# 4  Burger King

# %%
orders = pd.read_csv('data/Orders.csv')

# %%
points = pd.read_csv('data/Points.csv')

# %%
points
# Out:
#                                                 address  \
# 0     942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1     2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2     1112, Next to KIMS Medical College, 17th Cross...
# 3     1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4     10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                 ...
# 8787  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 8788  ITPL Main Road, KIADB Export Promotion Industr...
# 8789      107/PA, ITPL Main Road, Whitefield, Bangalore
# 8790  44, Kodigehalli to Hoodi Main Road, Mahadevapu...
# 8791  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                    name online_order  \
# 0                                                 Jalsa          Yes
# 1                                        Spice Elephant          Yes
# 2                                       San Churro Cafe          Yes
# ...

# %%
# points = points.drop(columns='Unnamed: 0')
# points.to_csv('data/Points.csv', index = False)

# %%
# orders.drop('Unnamed: 0', axis=1, inplace=True)
orders
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 32434484   2977660   206209            13          1                 12
# 32434485   2977660   206209            13          1                 12
# 32434486   2977660   206209            13          1                 12
# 32434487   2977660   206209            13          1                 12
# 32434488   2977660   206209            13          1                 12
#
#           days_since_last_order  product_id  reordered
# ...

# %%
products['Point_id'] = np.random.choice(points.index, size=len(products))

# %%
products.to_csv('data/Products.csv', index=False)

# %%
# orders.to_csv('data/Orders.csv', index=False)

# %%
# Out:
# array([ 734, 5763, 2885])

# %%
products_count = len(final_products['Name'])
products_count
# Out:
# 49688

# %%
full_count = int(products_count / len(points))
rest_count = products_count - len(points) * full_count

# %%
rest_count
# Out:
# -3064

# %%
aisles = pd.read_csv('instacart-market-basket-analysis/aisles.csv')
departments = pd.read_csv('instacart-market-basket-analysis/departments.csv')
order_products_prior = pd.read_csv('instacart-market-basket-analysis/order_products__prior.csv')
order_products_train = pd.read_csv('instacart-market-basket-analysis/order_products__train.csv')
orders = pd.read_csv('instacart-market-basket-analysis/orders.csv')
products = pd.read_csv('instacart-market-basket-analysis/products.csv')
sample_submission = pd.read_csv('instacart-market-basket-analysis/sample_submission.csv')

# %%
order_products_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
table = orders.merge(order_products_prior, on='order_id')

# %%
table = table.drop(['eval_set', 'add_to_cart_order'], axis=1)
table.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  reordered
# 0                     NaN         196          0
# 1                     NaN       14084          0
# 2                     NaN       12427          0
# 3                     NaN       26088          0
# 4                     NaN       26405          0

# %%
table.rename(columns={'days_since_prior_order': 'days_since_last_order'}, inplace=True)

# %%
table.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_last_order  product_id  reordered
# 0                    NaN         196          0
# 1                    NaN       14084          0
# 2                    NaN       12427          0
# 3                    NaN       26088          0
# 4                    NaN       26405          0

# %%
table.to_csv('data/Orders.csv')

# %%
final_products['Name'] = products.product_name

# %%
final_products
# Out:
#                                                  Name       BarCode  Price  \
# 0                          Chocolate Sandwich Cookies  887251667718  25.98
# 1                                    All-Seasons Salt  981490261909  40.47
# 2                Robust Golden Unsweetened Oolong Tea  142757679574  13.62
# 3   Smart Ones Classic Favorites Mini Rigatoni Wit...  524644824261  23.57
# 4                           Green Chile Anytime Sauce  497380578678  39.31
# ..                                                ...           ...    ...
# 95            Sprinklez Confetti Fun Organic Toppings  498724896989  21.18
# 96                        Organic Chamomile Lemon Tea  932108776132  25.96
# 97                          2% Yellow American Cheese  436158446698  26.06
# 98                        Local Living Butter Lettuce  747096923553   6.99
# 99            Peanut Butter & Strawberry Jam Sandwich  724497165763   9.92
#
#     LoaltyCoeff
# 0          0.04
# 1          0.24
# ...

# %%
n = products.product_name.count()

new_products = pd.DataFrame({
    'Name': products.product_name, 
    'BarCode': [str(i) for i in np.random.randint(low=10**11, high=10**12 - 1, size=n)],
    'Price': [round(i, 2) for i in 50 * np.random.random(size=n)],
    'LoaltyCoeff': [round(i, 2) for i in np.random.random(size=n)]
    })

new_products.to_csv('data/Products.csv', index=False)

# %%
# products.to_csv('data/Products.csv', index=False)

# %%
# orders = pd.read_csv('data/orders.csv')
# orders
